# %% [markdown]
# #### **IMPORTING REQUIRED PYTHON MODULE**

# %%
import pandas as pd 
from tabulate import tabulate 
import pprint

# %% [markdown]
# #### **READING CSV DATA USING PANDAS**

# %%
df = pd.read_csv(
    "/home/ritik/python-foundations-to-mastery/Pandas/retail_dataset/raw_customers.csv"
)

# %% [markdown]
# #### **BREAKING DATA BY DOMAIN**

# %%
customer_identity = ['customer_id', 'title', 'first_name', 'last_name', 'full_name', 'gender', 'is_active']
customer_address = ['customer_id', 'address', 'city', 'state', 'state_abbr', 'state_full', 'zip_code', 'country', 'region']
customer_content = ['customer_id', 'email', 'phone']
customer_business_info = ['customer_id','customer_segment', 'loyalty_points','preferred_channel', 'annual_income_usd', 'company' ]
customer_dates = ['customer_id','date_of_birth', 'age', 'account_created_date']

# %% [markdown]
# #### **CREATING DATAFRAME FOR EATCH DOMAIN**

# %%
customer_identity_df = df[customer_identity]
customer_address_df = df[customer_address]
customer_content_df = df[customer_content]
customer_business_info_df = df[customer_business_info]
customer_dates_df = df[customer_dates]

# %% [markdown]
# #### **DATA OVERVIEW OF CUSTOMER_IDENTITY_DATAFRAME**

# %%
print(
    tabulate(
        customer_identity_df.sample(10),
        headers='keys',
        tablefmt='simple_grid'
    )
)
# Out:
# ┌─────┬───────────────┬─────────┬──────────────┬─────────────┬──────────────────────┬──────────┬─────────────┐
# │     │   customer_id │ title   │ first_name   │ last_name   │ full_name            │ gender   │ is_active   │
# ├─────┼───────────────┼─────────┼──────────────┼─────────────┼──────────────────────┼──────────┼─────────────┤
# │ 598 │          1357 │ nan     │ Donna        │ Rivera      │ Donna Rivera         │ Female   │ Y           │
# ├─────┼───────────────┼─────────┼──────────────┼─────────────┼──────────────────────┼──────────┼─────────────┤
# │ 124 │          1477 │ Ms.     │ Dorothy      │ Robinson    │ Ms. Dorothy Robinson │ female   │ Yes         │
# ├─────┼───────────────┼─────────┼──────────────┼─────────────┼──────────────────────┼──────────┼─────────────┤
# │ 444 │          1269 │ nan     │ Richard      │ CLARK       │ Richard Clark        │ nan      │ 1           │
# ├─────┼───────────────┼─────────┼──────────────┼─────────────┼──────────────────────┼──────────┼─────────────┤
# │ 484 │          1421 │ nan     │ Benjamin     │ Garcia      │ Benjamin Garcia      │ nan      │ N           │
# ├─────┼───────────────┼─────────┼──────────────┼─────────────┼──────────────────────┼──────────┼─────────────┤
# │ 466 │          1324 │ Prof.   │ Daniel       │ Roberts     │ Prof. Daniel Roberts │ nan      │ TRUE        │
# ├─────┼───────────────┼─────────┼──────────────┼─────────────┼──────────────────────┼──────────┼─────────────┤
# │ 173 │          1122 │ Mrs.    │ JERRY        │ Sanders     │ Mrs. Jerry Sanders   │ Male     │ Y           │
# ├─────┼───────────────┼─────────┼──────────────┼─────────────┼──────────────────────┼──────────┼─────────────┤
# │ 438 │          1137 │ nan     │ Carolyn      │ Cox         │ Carolyn Cox          │ FEMALE   │ Yes         │
# ├─────┼───────────────┼─────────┼──────────────┼─────────────┼──────────────────────┼──────────┼─────────────┤
# │ 164 │          1332 │ nan     │ Aaron        │ green       │ Aaron Green          │ F        │ Yes         │
# ├─────┼───────────────┼─────────┼──────────────┼─────────────┼──────────────────────┼──────────┼─────────────┤
# │ 371 │          1575 │ nan     │ Mark         │ Wright      │ Mark Wright          │ male     │ 0           │
# ├─────┼───────────────┼─────────┼──────────────┼─────────────┼──────────────────────┼──────────┼─────────────┤
# │  52 │          1250 │ Ms.     │ Mark         │ James       │ Ms. Mark James       │ NB       │ No          │
# └─────┴───────────────┴─────────┴──────────────┴─────────────┴──────────────────────┴──────────┴─────────────┘

# %% [markdown]
# ##### *Data quality check using pandas*
